# %%
# !nvidia-smi
# Out:
# Fri May 21 05:46:40 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %cd R-BERT\ on\ AN\ data/
# Out:
# /content/drive/MyDrive/R-BERT on AN data

# %%
# %cd R-RoBERTa/
# Out:
# /content/drive/MyDrive/R-BERT on AN data/R-RoBERTa

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 748.8MB 25kB/s
# ...
#      |████████████████████████████████| 1.1MB 34.7MB/s
# ...
#      |████████████████████████████████| 1.2MB 32.0MB/s
# ...
#      |████████████████████████████████| 3.0MB 43.5MB/s
# ...
#      |████████████████████████████████| 901kB 36.1MB/s
# ...
# ERROR: torchvision 0.9.1+cu101 has requirement torch==1.8.1, but you'll have torch 1.6.0 which is incompatible.
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.6.0 which is incompatible.
# ...
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
# ...

# %%
# !python3 main.py --do_train --do_eval --max_seq_len=128 --save_steps=250 #--train_batch_size=8
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration:  92% 968/1049 [06:31<00:31,  2.58it/s]
# Iteration:  92% 969/1049 [06:31<00:31,  2.58it/s]
# Iteration:  92% 970/1049 [06:32<00:30,  2.58it/s]
# Iteration:  93% 971/1049 [06:32<00:30,  2.59it/s]
# Iteration:  93% 972/1049 [06:32<00:29,  2.59it/s]
# Iteration:  93% 973/1049 [06:33<00:29,  2.59it/s]
# Iteration:  93% 974/1049 [06:33<00:28,  2.60it/s]
# Iteration:  93% 975/1049 [06:34<00:28,  2.60it/s]
# Iteration:  93% 976/1049 [06:34<00:28,  2.60it/s]
# Iteration:  93% 977/1049 [06:34<00:27,  2.59it/s]
# Iteration:  93% 978/1049 [06:35<00:27,  2.59it/s]
# Iteration:  93% 979/1049 [06:35<00:27,  2.59it/s]
# Iteration:  93% 980/1049 [06:35<00:26,  2.59it/s]
# Iteration:  94% 981/1049 [06:36<00:26,  2.59it/s]
# Iteration:  94% 982/1049 [06:36<00:25,  2.60it/s]
# Iteration:  94% 983/1049 [06:37<00:25,  2.60it/s]
# Iteration:  94% 984/1049 [06:37<00:25,  2.59it/s]
# Iteration:  94% 985/1049 [06:37<00:24,  2.59it/s]
# ...
